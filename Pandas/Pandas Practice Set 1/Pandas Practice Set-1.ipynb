# %%
# 1. Write a Pandas program to read a csv file from a specified source and print the first 5 rows.

import pandas as pd
df = pd.read_csv('diamonds.csv',index_col=0)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# 2. Write a Pandas program to read a dataset from diamonds DataFrame and modify the default columns values and 
# print the first 6 rows

df[['carat','cut','x','y','z']].head(6)
# Out:
#    carat        cut     x     y     z
# 1   0.23      Ideal  3.95  3.98  2.43
# 2   0.21    Premium  3.89  3.84  2.31
# 3   0.23       Good  4.05  4.07  2.31
# 4   0.29    Premium  4.20  4.23  2.63
# 5   0.31       Good  4.34  4.35  2.75
# 6   0.24  Very Good  3.94  3.96  2.48

# %%
# 3. Write a Pandas program to select a series from diamonds DataFrame. Print the content of the series.

diamonds = pd.read_csv('diamonds.csv',index_col=0)
diamonds['carat']
# Out:
# 1        0.23
# 2        0.21
# 3        0.23
# 4        0.29
# 5        0.31
#          ...
# 53936    0.72
# 53937    0.72
# 53938    0.70
# 53939    0.86
# 53940    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
# 4. Write a Pandas program to create a new 'Quality -color' Series (use bracket notation to define the Series name) 
# of the diamonds DataFrame.

diamonds['Quality-color'] = 'Pure'
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 1              Pure
# 2              Pure
# 3              Pure
# 4              Pure
# 5              Pure
# ...             ...
# 53936          Pure
# 53937          Pure
# 53938          Pure
# 53939          Pure
# 53940          Pure
#
# [53940 rows x 11 columns]

# %%
# 5. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

diamonds.shape
# Out:
# (53940, 11)

# %%
diamonds.dtypes
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# Quality-color     object
# dtype: object

# %%
# 6 Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

diamonds.describe(include='object')
# Out:
#           cut  color clarity Quality-color
# count   53940  53940   53940         53940
# unique      5      7       8             1
# top     Ideal      G     SI1          Pure
# freq    21551  11292   13065         53940

# %%
# 7. Write a Pandas program to rename two of the columns of the diamonds Dataframe

diamonds.rename(columns={'x':'A','y':'B','z':'C'})
# Out:
#        carat        cut color clarity  depth  table  price     A     B     C  \
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 1              Pure
# 2              Pure
# 3              Pure
# 4              Pure
# 5              Pure
# ...             ...
# 53936          Pure
# 53937          Pure
# 53938          Pure
# 53939          Pure
# 53940          Pure
#
# [53940 rows x 11 columns]

# %%
# 8. Write a Pandas program to rename all the columns of the diamonds Dataframe.

diamonds.rename(columns={
                        'carat':'N_Carat',
                        'cut':'N_Cut',
                        'color':'N_Color',
                        'clarity':'N_Clarity',
                        'depth':'N_Depth',
                        'table':'N_Table',
                        'price':'N_Price',
                        'x':'N_X',
                        'y':'N_Y',
                        'z':'N_Z',
                        'Quality-color':'N_Quality-color'})
# Out:
#        N_Carat      N_Cut N_Color N_Clarity  N_Depth  N_Table  N_Price   N_X  \
# 1         0.23      Ideal       E       SI2     61.5     55.0      326  3.95
# 2         0.21    Premium       E       SI1     59.8     61.0      326  3.89
# 3         0.23       Good       E       VS1     56.9     65.0      327  4.05
# 4         0.29    Premium       I       VS2     62.4     58.0      334  4.20
# 5         0.31       Good       J       SI2     63.3     58.0      335  4.34
# ...        ...        ...     ...       ...      ...      ...      ...   ...
# 53936     0.72      Ideal       D       SI1     60.8     57.0     2757  5.75
# 53937     0.72       Good       D       SI1     63.1     55.0     2757  5.69
# 53938     0.70  Very Good       D       SI1     62.8     60.0     2757  5.66
# 53939     0.86    Premium       H       SI2     61.0     58.0     2757  6.15
# 53940     0.75      Ideal       D       SI2     62.2     55.0     2757  5.83
#
#         N_Y   N_Z N_Quality-color
# 1      3.98  2.43            Pure
# 2      3.84  2.31            Pure
# 3      4.07  2.31            Pure
# 4      4.23  2.63            Pure
# 5      4.35  2.75            Pure
# ...     ...   ...             ...
# 53936  5.76  3.50            Pure
# 53937  5.75  3.61            Pure
# 53938  5.68  3.56            Pure
# 53939  6.12  3.74            Pure
# 53940  5.87  3.64            Pure
#
# [53940 rows x 11 columns]

# %%
# 9. Write a Pandas program to remove the second column of the diamonds Dataframe.
diamonds.drop('cut',axis=1)
# Out:
#        carat color clarity  depth  table  price     x     y     z  \
# 1       0.23     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 1              Pure
# 2              Pure
# 3              Pure
# 4              Pure
# 5              Pure
# ...             ...
# 53936          Pure
# 53937          Pure
# 53938          Pure
# 53939          Pure
# 53940          Pure
#
# [53940 rows x 10 columns]

# %%
# 10. Write a Pandas program to remove multiple columns at once of the diamonds Dataframe.
diamonds.drop(['cut','clarity','depth'],axis=1)
# Out:
#        carat color  table  price     x     y     z Quality-color
# 1       0.23     E   55.0    326  3.95  3.98  2.43          Pure
# 2       0.21     E   61.0    326  3.89  3.84  2.31          Pure
# 3       0.23     E   65.0    327  4.05  4.07  2.31          Pure
# 4       0.29     I   58.0    334  4.20  4.23  2.63          Pure
# 5       0.31     J   58.0    335  4.34  4.35  2.75          Pure
# ...      ...   ...    ...    ...   ...   ...   ...           ...
# 53936   0.72     D   57.0   2757  5.75  5.76  3.50          Pure
# 53937   0.72     D   55.0   2757  5.69  5.75  3.61          Pure
# 53938   0.70     D   60.0   2757  5.66  5.68  3.56          Pure
# 53939   0.86     H   58.0   2757  6.15  6.12  3.74          Pure
# 53940   0.75     D   55.0   2757  5.83  5.87  3.64          Pure
#
# [53940 rows x 8 columns]

# %%
# 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe.
diamonds.drop([1,2,3],axis=0)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 6       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 8       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 4              Pure
# 5              Pure
# 6              Pure
# 7              Pure
# 8              Pure
# ...             ...
# 53936          Pure
# 53937          Pure
# 53938          Pure
# 53939          Pure
# 53940          Pure
#
# [53937 rows x 11 columns]

# %%
# 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.
diamonds['cut'].sort_values(ascending=True)
# Out:
# 3851          Fair
# 51465         Fair
# 51467         Fair
# 10238         Fair
# 10761         Fair
#            ...
# 7403     Very Good
# 43102    Very Good
# 16894    Very Good
# 16899    Very Good
# 21165    Very Good
# Name: cut, Length: 53940, dtype: object

# %%
# 13. Write a Pandas program to sort the 'price' Series in descending order (returns a Series) of diamonds Dataframe.
diamonds['price'].sort_values(ascending=False)
# Out:
# 27750    18823
# 27749    18818
# 27748    18806
# 27747    18804
# 27746    18803
#          ...
# 5          335
# 4          334
# 3          327
# 2          326
# 1          326
# Name: price, Length: 53940, dtype: int64

# %%
# 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and 
# descending order.
diamonds['carat'].sort_values(ascending=True)
# Out:
# 31594    0.20
# 31598    0.20
# 31597    0.20
# 31596    0.20
# 31595    0.20
#          ...
# 26000    4.01
# 25999    4.01
# 27131    4.13
# 27631    4.50
# 27416    5.01
# Name: carat, Length: 53940, dtype: float64

# %%
diamonds['carat'].sort_values(ascending=False)
# Out:
# 27416    5.01
# 27631    4.50
# 27131    4.13
# 26000    4.01
# 25999    4.01
#          ...
# 31593    0.20
# 31592    0.20
# 31602    0.20
# 15       0.20
# 31597    0.20
# Name: carat, Length: 53940, dtype: float64

# %%
# 15. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3


diamonds.loc[(diamonds['carat'] > 0.3)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 14      0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 24      0.31  Very Good     J     SI1   59.4   62.0    353  4.39  4.43  2.62
# 25      0.31  Very Good     J     SI1   58.1   62.0    353  4.44  4.47  2.59
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 5              Pure
# 14             Pure
# 16             Pure
# 24             Pure
# 25             Pure
# ...             ...
# 53936          Pure
# 53937          Pure
# 53938          Pure
# 53939          Pure
# 53940          Pure
#
# [49737 rows x 11 columns]

# %%
# 16. Write a Pandas program to convert a python list to pandas series.
l = [10,20,30,40,50]

pd.Series(l)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# 17. Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

diamonds.loc[(diamonds['x']>5) & (diamonds['y']>5) & (diamonds['z']>5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y  \
# 11779   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28
# 13003   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70
# 13119   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95
# 13563   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56
# 13758   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...
# 27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97
# 27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47
# 48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15
# 49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80
# 49906   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04
#
#            z Quality-color
# 11779   5.12          Pure
# 13003   5.36          Pure
# 13119   5.23          Pure
# 13563   5.04          Pure
# 13758   5.36          Pure
# ...      ...           ...
# 27749   5.04          Pure
# 27750   5.16          Pure
# 48411  31.80          Pure
# 49190   5.12          Pure
# 49906   5.06          Pure
#
# [1457 rows x 11 columns]

# %%
# 18. Write a Pandas program to find the diamonds that are either Premium or Ideal.

diamonds.loc[(diamonds['cut'] == 'Premium') | (diamonds['cut'] == 'Ideal')]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 1       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 4       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53932   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53935   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53936   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 1              Pure
# 2              Pure
# 4              Pure
# 12             Pure
# 13             Pure
# ...             ...
# 53932          Pure
# 53935          Pure
# 53936          Pure
# 53939          Pure
# 53940          Pure
#
# [35342 rows x 11 columns]

# %%
# 19. Write a Pandas program to find the diamonds that are with a Fair or Good or Premium
diamonds.loc[(diamonds['cut'] == 'Fair') | (diamonds['cut'] == 'Good') | (diamonds['cut'] == 'Premium')]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 2       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 9       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53932   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53935   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53937   0.72     Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
#       Quality-color
# 2              Pure
# 3              Pure
# 4              Pure
# 5              Pure
# 9              Pure
# ...             ...
# 53931          Pure
# 53932          Pure
# 53935          Pure
# 53937          Pure
# 53939          Pure
#
# [20307 rows x 11 columns]

# %%
# 20. Write a Pandas program to display all column labels of diamonds DataFrame.
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'Quality-color'],
#       dtype='object')

# %%
# 21. Write a Pandas program to read only a subset of 3 rows from diamonds DataFrame
diamonds.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
#
#   Quality-color
# 1          Pure
# 2          Pure
# 3          Pure

# %%
# 22. Write a Pandas program to iterate through diamonds DataFrame.

# %%
# 24. Write a Pandas program to include only numeric columns in the diamonds DataFrame.

# %%
# 25. Write a Pandas program to pass a list of data types to only describe certain types of diamonds DataFrame.

# %%
# 26. Write a Pandas program to calculate the mean of each numeric column of diamonds DataFrame.
diamonds.mean()
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
# 27. Write a Pandas program to calculate the mean of each row of diamonds DataFrame. 
diamonds.mean(axis=1).head()
# Out:
# 1    64.727143
# 2    65.292857
# 3    65.651429
# 4    66.535714
# 5    66.864286
# dtype: float64

# %%
# 28. Write a Pandas program to calculate the mean of price for each cut of diamonds DataFrame. 
#diamonds.head()

diamonds.groupby('cut').price.mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
# 29. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame. 
diamonds.groupby('cut').price.describe()
# Out:
#              count         mean          std    min      25%     50%      75%  \
# cut
# Fair        1610.0  4358.757764  3560.386612  337.0  2050.25  3282.0  5205.50
# Good        4906.0  3928.864452  3681.589584  327.0  1145.00  3050.5  5028.00
# Ideal      21551.0  3457.541970  3808.401172  326.0   878.00  1810.0  4678.50
# Premium    13791.0  4584.257704  4349.204961  326.0  1046.00  3185.0  6296.00
# Very Good  12082.0  3981.759891  3935.862161  336.0   912.00  2648.0  5372.75
#
#                max
# cut
# Fair       18574.0
# Good       18788.0
# Ideal      18806.0
# Premium    18823.0
# Very Good  18818.0

# %%
# 30. Write a Pandas program to create a side-by-side bar plot of the diamonds DataFrame.
diamonds.groupby('cut').mean().plot(kind='bar',figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='cut'>

# %%
# 31. Write a Pandas program to count how many times each value in cut series of diamonds DataFrame occurs.
diamonds['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
# 32. Write a Pandas program to display percentages of each value of cut series occurs in diamonds DataFrame. 
diamonds['cut'].value_counts(normalize=True)
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %%
# 33. Write a Pandas program to display the unique values in cut series of diamonds DataFrame. 
diamonds['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# 34. Write a Pandas program to count the number of unique values in cut series of diamonds DataFrame. 
diamonds['cut'].nunique()
# Out:
# 5

# %%
# 35. Write a Pandas program to compute a cross-tabulation of two Series in diamonds DataFrame.
pd.crosstab(diamonds['price'],diamonds['cut'])
# Out:
# cut    Fair  Good  Ideal  Premium  Very Good
# price
# 326       0     0      1        1          0
# 327       0     1      0        0          0
# 334       0     0      0        1          0
# 335       0     1      0        0          0
# 336       0     0      0        0          2
# ...     ...   ...    ...      ...        ...
# 18803     0     0      0        0          1
# 18804     0     0      1        0          0
# 18806     0     0      1        0          0
# 18818     0     0      0        0          1
# 18823     0     0      0        1          0
#
# [11602 rows x 5 columns]

# %%
# 36. Write a Pandas program to calculate various summary statistics of carat series of diamonds DataFrame. 
diamonds['carat'].describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
# 37. Write a Pandas program to create a histogram of the 'carat' Series (distribution of a numerical variable) 
# of diamonds DataFrame. 
diamonds['carat'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 38. Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut' series of diamonds DataFrame.
diamonds['cut'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 39. Write a Pandas program to create a DataFrame of booleans (True if missing, False if not missing) from 
# diamonds DataFrame.
diamonds.isnull()
# Out:
#        carat    cut  color  clarity  depth  table  price      x      y      z  \
# 1      False  False  False    False  False  False  False  False  False  False
# 2      False  False  False    False  False  False  False  False  False  False
# 3      False  False  False    False  False  False  False  False  False  False
# 4      False  False  False    False  False  False  False  False  False  False
# 5      False  False  False    False  False  False  False  False  False  False
# ...      ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 53936  False  False  False    False  False  False  False  False  False  False
# 53937  False  False  False    False  False  False  False  False  False  False
# 53938  False  False  False    False  False  False  False  False  False  False
# 53939  False  False  False    False  False  False  False  False  False  False
# 53940  False  False  False    False  False  False  False  False  False  False
#
#        Quality-color
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# ...              ...
# 53936          False
# 53937          False
# 53938          False
# 53939          False
# 53940          False
#
# [53940 rows x 11 columns]

# %%
# 40. Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame. 
diamonds.isnull().sum()
# Out:
# carat            0
# cut              0
# color            0
# clarity          0
# depth            0
# table            0
# price            0
# x                0
# y                0
# z                0
# Quality-color    0
# dtype: int64

# %%
# 41. Write a Pandas program to check the number of rows and columns and drop those row if 'any' values are 
# missing in a row of diamonds DataFrame. 
diamonds.dropna(how='any').shape
# Out:
# (53940, 11)

# %%
# 42. Write a Pandas program to drop a row if any or all values in a row are missing of diamonds DataFrame 
# on two specific columns. 
diamonds.dropna(how='any')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 1       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# 1              Pure
# 2              Pure
# 3              Pure
# 4              Pure
# 5              Pure
# ...             ...
# 53936          Pure
# 53937          Pure
# 53938          Pure
# 53939          Pure
# 53940          Pure
#
# [53940 rows x 11 columns]

# %%
# 43. Write a Pandas program to set an existing column as the index of diamonds DataFrame. 
diamonds.set_index('carat')
# Out:
#              cut color clarity  depth  table  price     x     y     z  \
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 0.72       Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 0.72        Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 0.70   Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 0.86     Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 0.75       Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-color
# carat
# 0.23           Pure
# 0.21           Pure
# 0.23           Pure
# 0.29           Pure
# 0.31           Pure
# ...             ...
# 0.72           Pure
# 0.72           Pure
# 0.70           Pure
# 0.86           Pure
# 0.75           Pure
#
# [53940 rows x 10 columns]

# %%
# 44. Write a Pandas program to set an existing column as the index of diamonds DataFrame and restore the 
# index name, and move the index back to a column.
diamonds.set_index('carat',inplace=True)

# %%
diamonds.reset_index('carat',inplace=True)

# %%
# 45. Write a Pandas program to access a specified Series index and the Series values of diamonds DataFrame.

# %%
# 46. Write a Pandas program to sort a Series by its values and index of diamonds DataFrame.

# %%
# 47. Write a Pandas program to calculate the multiply of length, width and depth for each cut of diamonds DataFrame.

# %%
# 48. Write a Pandas program to concatenate the diamonds DataFrame with the 'color' Series.

# %%
# 49. Write a Pandas program to read specified rows and all columns of diamonds DataFrame.

# %%
# 50. Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds DataFrame.

# %%
# 51. Write a Pandas program to read rows 2 through 5 and all columns of diamonds DataFrame.

# %%
# 52. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' and 'price' of diamonds DataFrame.

# %%
# 53. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' through 'price' (inclusive) of 
# diamonds DataFrame.

# %%
# 54. Write a Pandas program to read rows in which the 'cut' is 'Premium', column 'color' of diamonds DataFrame.

# %%
#55. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
# 56. Write a Pandas program to read rows in positions 0 through 4, columns in positions 1 through 4 of diamonds DataFrame.

# %%
# 57. Write a Pandas program to read rows in positions 0 through 4 (exclusive) and all columns of diamonds DataFrame.

# %%
# 58. Write a Pandas program to read rows 2 through 5 (inclusive), columns in positions 0 through 2 (exclusive) 
# of diamonds DataFrame.

# %%
# 59. Write a Pandas program to print a concise summary of diamonds DataFrame.

# %%
# 60. Write a Pandas program to get the true memory usage by diamonds DataFrame.

# %%
# 61. Write a Pandas program to calculate the memory usage for each Series (in bytes) of diamonds DataFrame.

# %%
# 62. Write a Pandas program to get randomly sample rows from diamonds DataFrame.

# %%
# 63. Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and 
# store the remaining 25% of the rows in another DataFrame.

# %%
# 64. Write a Pandas program to read the diamonds DataFrame and detect duplicate color.

# %%
# 65. Write a Pandas program to count the duplicate rows of diamonds DataFrame.
